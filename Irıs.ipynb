# %%
# Scatterplot Matrisi

# %%
##Veri Seti Hikayesi : Veri seti içinde bazı çiçek türleri var ve bu türlerin özelliklerini
##ifade eden değişkenler var. Yaprakları ile ilgili uzunluk, genişlik
## vb. şekilde bilgileri ifade eden bir veri setidir.

# %%
import seaborn as sns
iris= sns.load_dataset("iris")
df= iris.copy()
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
df.dtypes
# Out:
# sepal_length    float64
# sepal_width     float64
# petal_length    float64
# petal_width     float64
# species          object
# dtype: object

# %%
df.shape
# Out:
# (150, 5)

# %%
##değişken dağılımlarını ifade etmektedir.
##eksenlerden yapılacak kesişimler ile değ
sns.pairplot(df);

# %%
sns.pairplot(df, hue = "species");

# %%
sns.pairplot(df, kind = "reg");
